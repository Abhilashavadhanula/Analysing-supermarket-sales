# %% [markdown]
# ### Data Analysis for supermarket sales

# %%
import pandas as pd
import numpy as np
sales=pd.read_csv('~/downloads/sales.csv')
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# 2   Clothing     57         2    114    Cash       5
# 3   Sporting     89         4    356    Gpay       1
# 4      Books     82         5    410    Cash       4

# %%
##Changing the default theam of notebook 
# pip install jupytertheams
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme('monokai')

# %%
## Accessing different parts of data
sales['Invoice ID']
# Out:
# 0      460489604
# 1      471006167
# 2      411909258
# 3      487313402
# 4      197763430
#          ...
# 995    818829599
# 996    556589713
# 997     82324424
# 998    783661702
# 999    759171975
# Name: Invoice ID, Length: 1000, dtype: int64

# %%
sales['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
## By using the iloc we can access the elements of the coustomers (individual )
sales.iloc[200]
# Out:
# Invoice ID      576523018
# Date            2/15/2018
# Time                12:35
# Gender               Male
# Location      Water tower
# City              Chicago
# Member                 No
# Category        Groceries
# Price                  82
# Quantity                1
# Total                  82
# Payment              Card
# Rating                  4
# Name: 200, dtype: object

# %%
## extracting the data from 200 to 210 records from the sales
sales[200:211]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 200   576523018  2/15/2018  12:35    Male  Water tower  Chicago     No
# 201   414119922  1/30/2018  11:07    Male  Water tower  Chicago     No
# 202   123247697   2/8/2018  20:03    Male   Brookfield  NewYork     No
# 203    40419058  1/26/2018  14:53    Male  Water tower  Chicago    Yes
# 204   890497298  2/25/2018  18:06  Female  Water tower  Chicago     No
# 205   885702268  1/28/2018  12:45    Male   Brookfield  NewYork     No
# 206   172252194  3/22/2018  20:10  Female    Park lane   Dallas     No
# 207   866140211  2/25/2018  13:34  Female    Park lane   Dallas     No
# 208   597678548  3/15/2018  17:35    Male  Water tower  Chicago    Yes
# 209   428818456  2/25/2018  18:50    Male    Park lane   Dallas    Yes
# 210   236950025   3/9/2018  12:40  Female   Brookfield  NewYork    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 200  Groceries     82         1     82    Card       4
# ...

# %%
## Selecting rows on a condition
## getting the information of only males
sales[sales['Gender']=='Male'].head()
# Out:
#    Invoice ID       Date   Time Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2   411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5   263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 2   Clothing     57         2    114    Cash       5
# 5   Clothing     52         4    208    Gpay       3
# 6   Clothing     81         3    243    Cash       4
# 7      Books     80         2    160    Cash       3

# %%
## sales above 100$
sales[sales['Total']>100].head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
#
#    Category  Price  Quantity  Total Payment  Rating
# 1   Fashion     35         5    175    Card       3
# 2  Clothing     57         2    114    Cash       5
# 3  Sporting     89         4    356    Gpay       1
# 4     Books     82         5    410    Cash       4
# 5  Clothing     52         4    208    Gpay       3

# %%
## sales less 100$
sales[sales['Total']<100].head()
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 0    460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 13   942406749  1/18/2018  15:20  Female  Water tower  Chicago    Yes
# 17    90524319  3/19/2018  18:18    Male    Park lane   Dallas    Yes
# 22   761515143  1/15/2018  16:08  Female    Park lane   Dallas     No
# 23    56578535  3/23/2018  10:11    Male  Water tower  Chicago    Yes
#
#      Category  Price  Quantity  Total Payment  Rating
# 0   Groceries     30         1     30    Cash       2
# 13   Clothing      9         6     54    Gpay       5
# 17   Clothing     23         1     23    Cash       3
# 22  Groceries     23         1     23    Gpay       3
# 23  Groceries     24         1     24    Gpay       2

# %%
sales['Payment'].unique()
# Out:
# array(['Cash', 'Card', 'Gpay'], dtype=object)

# %%
## extracting the information of the persons who made the transactions with the cash
sales[sales['Payment']=='Cash'].head(10)
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 0    460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 2    411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4    197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 6     99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7    188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 12   149894432  1/12/2018  11:12    Male    Park lane   Dallas     No
# 17    90524319  3/19/2018  18:18    Male    Park lane   Dallas    Yes
# 19   729486362   3/7/2018  12:50    Male  Water tower  Chicago     No
# 20   619639105  3/26/2018  19:48  Female   Brookfield  NewYork     No
#
#      Category  Price  Quantity  Total Payment  Rating
# 0   Groceries     30         1     30    Cash       2
# 2    Clothing     57         2    114    Cash       5
# ...

# %%
## Queries to find the conditioanl data
## by using the query meathod we can add the multiple conditions 
## implementing multiple quries

sales.query('100<Total<200')
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 9     562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10    388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 977   614557665  3/22/2018  17:16  Female    Park lane   Dallas     No
# 981   418253101  3/14/2018  12:25  Female   Brookfield  NewYork     No
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# ...

# %%
## We can add as many querys as we want
sales.query('Payment=="Cash" & City=="NewYork" & Total<50')
# Out:
#      Invoice ID       Date   Time  Gender    Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male  Brookfield  NewYork    Yes
# 81    336967276  1/19/2018  17:54    Male  Brookfield  NewYork     No
# 95    842361554  1/14/2018  16:17    Male  Brookfield  NewYork    Yes
# 159   582323814  1/13/2018  20:06    Male  Brookfield  NewYork    Yes
# 238   565456402  1/23/2018  14:51  Female  Brookfield  NewYork     No
# 257   874941247   3/1/2018  11:24  Female  Brookfield  NewYork     No
# 301   479562097  2/16/2018  14:03  Female  Brookfield  NewYork     No
# 382   376812677  1/10/2018  18:04  Female  Brookfield  NewYork     No
# 401   196926207   3/3/2018  13:08  Female  Brookfield  NewYork    Yes
# 499   253349866  2/16/2018  19:06    Male  Brookfield  NewYork    Yes
# 506   187709802  1/24/2018  10:43    Male  Brookfield  NewYork    Yes
# 514   148516620   2/8/2018  12:29  Female  Brookfield  NewYork     No
# ...

# %%
## Finding SUM, MAX ,MIN AND AVG
sales.sum()['Total']
# Out:
# 207788

# %%
sales.sum()['Quantity']
# Out:
# 4059

# %%
sales.max()
# Out:
# Invoice ID      999665753
# Date             3/9/2018
# Time                20:59
# Gender               Male
# Location      Water tower
# City              NewYork
# Member                Yes
# Category         Sporting
# Price                 100
# Quantity                7
# Total                 693
# Payment              Gpay
# Rating                  5
# dtype: object

# %%
sales.max()['Total']
# Out:
# 693

# %%
sales[sales['Total']==sales.max()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
sales.min()
# Out:
# Invoice ID        661405
# Date            1/1/2018
# Time               10:00
# Gender            Female
# Location      Brookfield
# City             Chicago
# Member                No
# Category           Books
# Price                  1
# Quantity               1
# Total                  1
# Payment             Card
# Rating                 1
# dtype: object

# %%
sales.min()['Total']
# Out:
# 1

# %%
sales[sales['Total']==sales['Total'].min()]
# Out:
#      Invoice ID       Date   Time  Gender   Location    City Member  \
# 184   801334050  1/21/2018  20:18  Female  Park lane  Dallas     No
# 587   646176653  3/10/2018  19:39    Male  Park lane  Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 184  Furniture      1         1      1    Gpay       2
# 587   Sporting      1         1      1    Cash       2

# %%
sales.mean()['Total']
# Out:
# 207.788

# %%
## Group by clause
sales.groupby('City').sum()
# Out:
#            Invoice ID  Price  Quantity  Total  Rating
# City
# Chicago  164244758326  16152      1307  65215    1023
# Dallas   160721744770  17289      1344  70432    1003
# NewYork  169526550245  17671      1408  72141     946

# %%
sales.groupby('City').sum()['Total']
# Out:
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
sales.groupby('Date').sum()
# Out:
#            Invoice ID  Price  Quantity  Total  Rating
# Date
# 1/1/2018   5754968491    722        42   2649      45
# 1/10/2018  5071442922    433        27   1116      25
# 1/11/2018  4596704479    397        34   1562      20
# 1/12/2018  5999941284    603        44   2625      36
# 1/13/2018  6152497894    435        50   2340      26
# ...               ...    ...       ...    ...     ...
# 3/5/2018   7176403264   1001        76   4616      48
# 3/6/2018   4759166414    459        50   1915      35
# 3/7/2018   5519232431    237        42   1048      24
# 3/8/2018   5365615999    759        38   2638      33
# 3/9/2018   6478665906    882        72   4300      48
#
# [89 rows x 5 columns]

# %%
sales.groupby('Date').sum()['Total']
# Out:
# Date
# 1/1/2018     2649
# 1/10/2018    1116
# 1/11/2018    1562
# 1/12/2018    2625
# 1/13/2018    2340
#              ...
# 3/5/2018     4616
# 3/6/2018     1915
# 3/7/2018     1048
# 3/8/2018     2638
# 3/9/2018     4300
# Name: Total, Length: 89, dtype: int64

# %%
sales.groupby('Category').sum()['Total']
# Out:
# Category
# Books        36103
# Clothing     35925
# Fashion      32778
# Furniture    34141
# Groceries    31236
# Sporting     37605
# Name: Total, dtype: int64

# %%
sales.groupby('Member').sum()['Total']
# Out:
# Member
# No     100245
# Yes    107543
# Name: Total, dtype: int64

# %% [markdown]
#  - 1) Answering each question on the bramch
# - 2) which location has highest and lowest sales
# - 3) Represemt the sales on bar chart
# - 4) Each location using a pie chart

# %%
location_list=sales.groupby('Location')
location=[x for x,y in location_list ]
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
sales.groupby('Location').sum()['Total']
# Out:
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(location,sales.groupby('Location').sum()['Total'])
plt.show()

# %%
plt.pie(sales.groupby('Location').sum()['Total'],labels=location,autopct='%1.1f%%')
plt.show()

# %%
## Which location has more female and male customers
location_sales=sales.groupby(['Gender','Location']).count()['Invoice ID']
location_sales
# Out:
# Gender  Location
# Female  Brookfield     179
#         Park lane      179
#         Water tower    143
# Male    Brookfield     161
#         Park lane      153
#         Water tower    185
# Name: Invoice ID, dtype: int64

# %%
## unstack meathod will help us to form a structured formate of data 
unstacked_sales=location_sales.unstack(level=0)
unstacked_sales
# Out:
# Gender       Female  Male
# Location
# Brookfield      179   161
# Park lane       179   153
# Water tower     143   185

# %%
## Bar graph
unstacked_sales.plot(kind='bar')

# %%
## Which branch has more numbers & less numbers?
## Which branch has highest rating and which branch has lowest

# %%
sales.head(5)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# 2   Clothing     57         2    114    Cash       5
# 3   Sporting     89         4    356    Gpay       1
# 4      Books     82         5    410    Cash       4

# %%
members=sales.groupby(['Member','Location']).count()['Invoice ID']
members
# Out:
# Member  Location
# No      Brookfield     173
#         Park lane      167
#         Water tower    159
# Yes     Brookfield     167
#         Park lane      165
#         Water tower    169
# Name: Invoice ID, dtype: int64

# %%
members.unstack()
# Out:
# Location  Brookfield  Park lane  Water tower
# Member
# No               173        167          159
# Yes              167        165          169

# %%
rating=sales.groupby('Location').mean()['Rating']
rating
# Out:
# Location
# Brookfield     2.782353
# Park lane      3.021084
# Water tower    3.118902
# Name: Rating, dtype: float64

# %%
rating.plot(kind='bar')

# %% [markdown]
# ## Questions
# - which city has more female shopping
# - who spends more men or women
# - which type of customer spends more member or non member
# - which product line sells more
# - which productline is popular more men or women

# %%
female_shoppers=sales.groupby(['Gender','City']).count()['Invoice ID']
female_shoppers
# Out:
# Gender  City
# Female  Chicago    143
#         Dallas     179
#         NewYork    179
# Male    Chicago    185
#         Dallas     153
#         NewYork    161
# Name: Invoice ID, dtype: int64

# %%
female_shoppers.unstack(level=0).plot(kind="bar")
plt.show()

# %%
sales.head(4)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# 2   Clothing     57         2    114    Cash       5
# 3   Sporting     89         4    356    Gpay       1

# %%
spend=sales.groupby('Gender').sum()['Total']
spend
# Out:
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
spend.plot(kind='bar')
plt.show()

# %%
member=sales.groupby('Member').sum()['Total']
member
# Out:
# Member
# No     100245
# Yes    107543
# Name: Total, dtype: int64

# %%
member.plot(kind='bar')
plt.show()

# %%
categort_sales=sales.groupby('Category').count()['Rating']
categort_sales
# Out:
# Category
# Books        165
# Clothing     170
# Fashion      153
# Furniture    160
# Groceries    174
# Sporting     178
# Name: Rating, dtype: int64

# %%
categort_sales.plot(kind='bar')
plt.show()

# %%
sales_m_w=sales.groupby(['Gender','Category']).count()['Rating']
sales_m_w
# Out:
# Gender  Category
# Female  Books        88
#         Clothing     81
#         Fashion      81
#         Furniture    78
#         Groceries    87
#         Sporting     86
# Male    Books        77
#         Clothing     89
#         Fashion      72
#         Furniture    82
#         Groceries    87
#         Sporting     92
# Name: Rating, dtype: int64

# %%
sales_m_w.unstack(level=0).plot(kind='bar')
plt.show()

# %%
## What days of the month makes more sales
sales['Date']
# Out:
# 0      1/25/2018
# 1      3/19/2018
# 2      2/25/2018
# 3      1/22/2018
# 4      2/18/2018
#          ...
# 995    3/26/2018
# 996    2/20/2018
# 997     2/6/2018
# 998    1/29/2018
# 999    1/31/2018
# Name: Date, Length: 1000, dtype: object

# %%
pd.to_datetime(sales['Date']).dt.month
# Out:
# 0      1
# 1      3
# 2      2
# 3      1
# 4      2
#       ..
# 995    3
# 996    2
# 997    2
# 998    1
# 999    1
# Name: Date, Length: 1000, dtype: int64

# %%
pd.to_datetime(sales['Date']).dt.year
# Out:
# 0      2018
# 1      2018
# 2      2018
# 3      2018
# 4      2018
#        ...
# 995    2018
# 996    2018
# 997    2018
# 998    2018
# 999    2018
# Name: Date, Length: 1000, dtype: int64

# %%
pd.to_datetime(sales['Date']).dt.day
# Out:
# 0      25
# 1      19
# 2      25
# 3      22
# 4      18
#        ..
# 995    26
# 996    20
# 997     6
# 998    29
# 999    31
# Name: Date, Length: 1000, dtype: int64

# %%
sales['Day']=pd.to_datetime(sales['Date']).dt.day

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# 2   Clothing     57         2    114    Cash       5   25
# 3   Sporting     89         4    356    Gpay       1   22
# 4      Books     82         5    410    Cash       4   18

# %%
day_sales=sales.groupby('Day').sum()['Total']

# %%
day_sales.head()
# Out:
# Day
# 1    6301
# 2    8247
# 3    8533
# 4    6593
# 5    9177
# Name: Total, dtype: int64

# %%
day_sales.plot()
plt.show()

# %%
## Which month makes most sales
sales['month']=pd.to_datetime(sales['Date']).dt.month

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day  month
# 0  Groceries     30         1     30    Cash       2   25      1
# 1    Fashion     35         5    175    Card       3   19      3
# 2   Clothing     57         2    114    Cash       5   25      2
# 3   Sporting     89         4    356    Gpay       1   22      1
# 4      Books     82         5    410    Cash       4   18      2

# %%
sales_by_month=sales.groupby('month').sum()['Total']
sales_by_month
# Out:
# month
# 1    71652
# 2    63850
# 3    72286
# Name: Total, dtype: int64

# %%
sales_by_month.plot(kind='bar')
plt.grid()
plt.show()

# %%
## What hours will make the most sales
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day  month
# 0  Groceries     30         1     30    Cash       2   25      1
# 1    Fashion     35         5    175    Card       3   19      3
# 2   Clothing     57         2    114    Cash       5   25      2
# 3   Sporting     89         4    356    Gpay       1   22      1
# 4      Books     82         5    410    Cash       4   18      2

# %%
sales['Hours']=pd.to_datetime(sales['Time']).dt.hour
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day  month  Hours
# 0  Groceries     30         1     30    Cash       2   25      1     16
# 1    Fashion     35         5    175    Card       3   19      3     16
# 2   Clothing     57         2    114    Cash       5   25      2     13
# 3   Sporting     89         4    356    Gpay       1   22      1     13
# 4      Books     82         5    410    Cash       4   18      2     15

# %%
sales_by_hours=sales.groupby('Hours').sum()['Total']

# %%
sales_by_hours.plot(grid=True)
plt.show()

# %%
## what time people make epayments
## what time people make cash payments

# %%
sales.groupby(['Payment','Hours']).count()['Invoice ID'].unstack(level=0).plot(kind='bar')
